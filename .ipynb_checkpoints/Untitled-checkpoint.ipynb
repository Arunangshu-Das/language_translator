# %%
# !pip3 install torch==1.8.2 torchvision==0.9.2 torchaudio===0.8.2 --extra-index-url https://download.pytorch.org/whl/lts/1.8/cu111
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/lts/1.8/cu111
# Collecting torch==1.8.2
#   Downloading https://download.pytorch.org/whl/lts/1.8/cu111/torch-1.8.2%2Bcu111-cp39-cp39-win_amd64.whl (3057.4 MB)
#      ---------------------------------------- 3.1/3.1 GB 792.9 kB/s eta 0:00:00
# Collecting torchvision==0.9.2
#   Downloading https://download.pytorch.org/whl/lts/1.8/cu111/torchvision-0.9.2%2Bcu111-cp39-cp39-win_amd64.whl (1.9 MB)
#      ---------------------------------------- 1.9/1.9 MB 1.8 MB/s eta 0:00:00
# Collecting torchaudio===0.8.2
#   Downloading https://download.pytorch.org/whl/lts/1.8/torchaudio-0.8.2-cp39-none-win_amd64.whl (109 kB)
#      ------------------------------------ 109.3/109.3 KB 275.2 kB/s eta 0:00:00
# Requirement already satisfied: numpy in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from torch==1.8.2) (1.22.3)
# Requirement already satisfied: typing-extensions in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from torch==1.8.2) (3.7.4.3)
# Requirement already satisfied: pillow>=4.1.1 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from torchvision==0.9.2) (9.2.0)
# Installing collected packages: torch, torchvision, torchaudio
#   Attempting uninstall: torch
#     Found existing installation: torch 1.12.1
#     Uninstalling torch-1.12.1:
#       Successfully uninstalled torch-1.12.1
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.13.1
#     Uninstalling torchvision-0.13.1:
#       Successfully uninstalled torchvision-0.13.1
# Successfully installed torch-1.8.2+cu111 torchaudio-0.8.2 torchvision-0.9.2+cu111
# WARNING: You are using pip version 22.0.4; however, version 22.2.2 is available.
# You should consider upgrading via the 'c:\users\user\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %%
# !pip install transformers ipywidgets gradio --upgrade
# Out:
# Collecting transformers
#   Downloading transformers-4.22.2-py3-none-any.whl (4.9 MB)
#      ---------------------------------------- 4.9/4.9 MB 1.7 MB/s eta 0:00:00
# Requirement already satisfied: ipywidgets in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (7.6.3)
# Collecting ipywidgets
#   Downloading ipywidgets-8.0.2-py3-none-any.whl (134 kB)
#      ------------------------------------ 134.4/134.4 KB 611.5 kB/s eta 0:00:00
# Collecting gradio
#   Downloading gradio-3.4.1-py3-none-any.whl (5.3 MB)
#      ---------------------------------------- 5.3/5.3 MB 814.6 kB/s eta 0:00:00
# Collecting tqdm>=4.27
#   Downloading tqdm-4.64.1-py2.py3-none-any.whl (78 kB)
#      ---------------------------------------- 78.5/78.5 KB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml>=5.1 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from transformers) (6.0)
# Collecting filelock
#   Downloading filelock-3.8.0-py3-none-any.whl (10 kB)
# Collecting regex!=2019.12.17
#   Downloading regex-2022.9.13-cp39-cp39-win_amd64.whl (267 kB)
#      -------------------------------------- 267.7/267.7 KB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: requests in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from transformers) (2.28.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from transformers) (21.0)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp39-cp39-win_amd64.whl (3.3 MB)
#      ---------------------------------------- 3.3/3.3 MB 1.1 MB/s eta 0:00:00
# Collecting huggingface-hub<1.0,>=0.9.0
#   Downloading huggingface_hub-0.10.0-py3-none-any.whl (163 kB)
#      -------------------------------------- 163.5/163.5 KB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from transformers) (1.22.3)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from ipywidgets) (5.0.5)
# Collecting jupyterlab-widgets~=3.0
#   Downloading jupyterlab_widgets-3.0.3-py3-none-any.whl (384 kB)
#      ------------------------------------ 384.1/384.1 KB 920.8 kB/s eta 0:00:00
# Collecting widgetsnbextension~=4.0
#   Downloading widgetsnbextension-4.0.3-py3-none-any.whl (2.0 MB)
#      ---------------------------------------- 2.0/2.0 MB 777.7 kB/s eta 0:00:00
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from ipywidgets) (6.2.0)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from ipywidgets) (7.26.0)
# Collecting uvicorn
#   Downloading uvicorn-0.18.3-py3-none-any.whl (57 kB)
#      ---------------------------------------- 57.4/57.4 KB 1.0 MB/s eta 0:00:00
# Requirement already satisfied: pandas in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from gradio) (1.3.2)
# Collecting ffmpy
#   Downloading ffmpy-0.3.0.tar.gz (4.8 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting pydub
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Collecting fsspec
#   Downloading fsspec-2022.8.2-py3-none-any.whl (140 kB)
#      ------------------------------------ 140.8/140.8 KB 925.9 kB/s eta 0:00:00
# Collecting httpx
#   Downloading httpx-0.23.0-py3-none-any.whl (84 kB)
#      ---------------------------------------- 84.8/84.8 KB 1.2 MB/s eta 0:00:00
# Collecting fastapi
#   Downloading fastapi-0.85.0-py3-none-any.whl (55 kB)
#      -------------------------------------- 55.3/55.3 KB 957.7 kB/s eta 0:00:00
# Collecting websockets
#   Downloading websockets-10.3-cp39-cp39-win_amd64.whl (98 kB)
#      ---------------------------------------- 98.6/98.6 KB 1.1 MB/s eta 0:00:00
# Collecting pydantic
#   Downloading pydantic-1.10.2-cp39-cp39-win_amd64.whl (2.1 MB)
#      ---------------------------------------- 2.1/2.1 MB 731.0 kB/s eta 0:00:00
# Collecting orjson
#   Downloading orjson-3.8.0-cp39-none-win_amd64.whl (197 kB)
#      -------------------------------------- 197.5/197.5 KB 1.1 MB/s eta 0:00:00
# Collecting python-multipart
#   Downloading python-multipart-0.0.5.tar.gz (32 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting aiohttp
#   Downloading aiohttp-3.8.3-cp39-cp39-win_amd64.whl (323 kB)
#      ------------------------------------ 323.5/323.5 KB 626.6 kB/s eta 0:00:00
# Requirement already satisfied: pillow in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from gradio) (9.2.0)
# Collecting pycryptodome
#   Downloading pycryptodome-3.15.0-cp35-abi3-win_amd64.whl (1.9 MB)
#      ---------------------------------------- 1.9/1.9 MB 702.4 kB/s eta 0:00:00
# Requirement already satisfied: matplotlib in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from gradio) (3.4.3)
# Collecting paramiko
#   Downloading paramiko-2.11.0-py2.py3-none-any.whl (212 kB)
#      ------------------------------------ 212.9/212.9 KB 564.4 kB/s eta 0:00:00
# Collecting h11<0.13,>=0.11
#   Using cached h11-0.12.0-py3-none-any.whl (54 kB)
# Collecting markdown-it-py[linkify,plugins]
#   Downloading markdown_it_py-2.1.0-py3-none-any.whl (84 kB)
#      -------------------------------------- 84.5/84.5 KB 527.0 kB/s eta 0:00:00
# Requirement already satisfied: jinja2 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from gradio) (3.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from huggingface-hub<1.0,>=0.9.0->transformers) (3.7.4.3)
# Requirement already satisfied: jupyter-client<8.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (7.0.1)
# Requirement already satisfied: tornado<7.0,>=4.2 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (6.1)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (1.4.1)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.2)
# Requirement already satisfied: pickleshare in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.7.5)
# Requirement already satisfied: decorator in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from ipython>=6.1.0->ipywidgets) (5.0.9)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.20)
# Requirement already satisfied: setuptools>=18.5 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from ipython>=6.1.0->ipywidgets) (56.0.0)
# Requirement already satisfied: pygments in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from ipython>=6.1.0->ipywidgets) (2.10.0)
# Requirement already satisfied: colorama in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.4)
# Requirement already satisfied: backcall in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.18.0)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from packaging>=20.0->transformers) (2.4.7)
# Requirement already satisfied: ipython-genutils in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from traitlets>=4.3.1->ipywidgets) (0.2.0)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.8.1-cp39-cp39-win_amd64.whl (56 kB)
#      -------------------------------------- 56.7/56.7 KB 749.0 kB/s eta 0:00:00
# Requirement already satisfied: attrs>=17.3.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from aiohttp->gradio) (21.2.0)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.1-cp39-cp39-win_amd64.whl (34 kB)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from aiohttp->gradio) (2.1.1)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.2-cp39-cp39-win_amd64.whl (28 kB)
# Collecting starlette==0.20.4
#   Downloading starlette-0.20.4-py3-none-any.whl (63 kB)
#      -------------------------------------- 63.6/63.6 KB 567.7 kB/s eta 0:00:00
# Collecting anyio<5,>=3.4.0
#   Downloading anyio-3.6.1-py3-none-any.whl (80 kB)
#      -------------------------------------- 80.6/80.6 KB 563.0 kB/s eta 0:00:00
# Collecting typing-extensions>=3.7.4.3
#   Using cached typing_extensions-4.4.0-py3-none-any.whl (26 kB)
# Requirement already satisfied: certifi in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from httpx->gradio) (2021.5.30)
# Collecting rfc3986[idna2008]<2,>=1.3
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Collecting httpcore<0.16.0,>=0.15.0
#   Downloading httpcore-0.15.0-py3-none-any.whl (68 kB)
#      ---------------------------------------- 68.4/68.4 KB 1.2 MB/s eta 0:00:00
# Collecting sniffio
#   Downloading sniffio-1.3.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from jinja2->gradio) (2.1.1)
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Collecting linkify-it-py~=1.0
#   Downloading linkify_it_py-1.0.3-py3-none-any.whl (19 kB)
# Collecting mdit-py-plugins
#   Downloading mdit_py_plugins-0.3.1-py3-none-any.whl (46 kB)
#      -------------------------------------- 46.5/46.5 KB 771.1 kB/s eta 0:00:00
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->gradio) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->gradio) (0.10.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->gradio) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from pandas->gradio) (2021.1)
# Collecting cryptography>=2.5
#   Downloading cryptography-38.0.1-cp36-abi3-win_amd64.whl (2.4 MB)
#      ---------------------------------------- 2.4/2.4 MB 474.7 kB/s eta 0:00:00
# Requirement already satisfied: six in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from paramiko->gradio) (1.15.0)
# Collecting bcrypt>=3.1.3
#   Downloading bcrypt-4.0.0-cp36-abi3-win_amd64.whl (153 kB)
#      ------------------------------------ 153.1/153.1 KB 351.8 kB/s eta 0:00:00
# Collecting pynacl>=1.0.1
#   Downloading PyNaCl-1.5.0-cp36-abi3-win_amd64.whl (212 kB)
#      ------------------------------------ 212.1/212.1 KB 516.4 kB/s eta 0:00:00
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from requests->transformers) (1.26.6)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from requests->transformers) (2.10)
# Requirement already satisfied: click>=7.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from uvicorn->gradio) (8.1.3)
# Requirement already satisfied: cffi>=1.12 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from cryptography>=2.5->paramiko->gradio) (1.14.6)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.2)
# Requirement already satisfied: pyzmq>=13 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (22.2.1)
# Requirement already satisfied: entrypoints in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (0.3)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (4.7.1)
# Requirement already satisfied: nest-asyncio>=1.5 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (1.5.1)
# Collecting uc-micro-py
#   Downloading uc_micro_py-1.0.1-py3-none-any.whl (6.2 kB)
# Requirement already satisfied: wcwidth in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=6.1.0->ipywidgets) (0.2.5)
# Requirement already satisfied: pycparser in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from cffi>=1.12->cryptography>=2.5->paramiko->gradio) (2.20)
# Requirement already satisfied: pywin32>=1.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (301)
# Building wheels for collected packages: ffmpy, python-multipart
#   Building wheel for ffmpy (setup.py): started
#   Building wheel for ffmpy (setup.py): finished with status 'done'
#   Created wheel for ffmpy: filename=ffmpy-0.3.0-py3-none-any.whl size=4709 sha256=7cff94d7c9c8ed85777debc10c2986b5094a8c3fda0ab3a275265e7218deaa87
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\91\e2\96\f676aa08bfd789328c6576cd0f1fde4a3d686703bb0c247697
#   Building wheel for python-multipart (setup.py): started
#   Building wheel for python-multipart (setup.py): finished with status 'done'
#   Created wheel for python-multipart: filename=python_multipart-0.0.5-py3-none-any.whl size=31670 sha256=26becf76e92b51d93c956ed01b2e5041abf0e8c6a6b5b8afe8033724c8937ac2
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\fe\04\d1\a10661cc45f03c3cecda50deb2d2c22f57b4e84a75b2a5987e
# Successfully built ffmpy python-multipart
# Installing collected packages: tokenizers, rfc3986, pydub, ffmpy, widgetsnbextension, websockets, uc-micro-py, typing-extensions, tqdm, sniffio, regex, python-multipart, pycryptodome, orjson, multidict, mdurl, jupyterlab-widgets, h11, fsspec, frozenlist, filelock, bcrypt, async-timeout, yarl, uvicorn, pynacl, pydantic, markdown-it-py, linkify-it-py, huggingface-hub, cryptography, anyio, aiosignal, transformers, starlette, paramiko, mdit-py-plugins, httpcore, aiohttp, httpx, fastapi, ipywidgets, gradio
#   Attempting uninstall: widgetsnbextension
#     Found existing installation: widgetsnbextension 3.5.1
#     Uninstalling widgetsnbextension-3.5.1:
#       Successfully uninstalled widgetsnbextension-3.5.1
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 3.7.4.3
#     Uninstalling typing-extensions-3.7.4.3:
#       Successfully uninstalled typing-extensions-3.7.4.3
#   Attempting uninstall: jupyterlab-widgets
#     Found existing installation: jupyterlab-widgets 1.0.0
#     Uninstalling jupyterlab-widgets-1.0.0:
#       Successfully uninstalled jupyterlab-widgets-1.0.0
#   Attempting uninstall: ipywidgets
#     Found existing installation: ipywidgets 7.6.3
#     Uninstalling ipywidgets-7.6.3:
#       Successfully uninstalled ipywidgets-7.6.3
# Successfully installed aiohttp-3.8.3 aiosignal-1.2.0 anyio-3.6.1 async-timeout-4.0.2 bcrypt-4.0.0 cryptography-38.0.1 fastapi-0.85.0 ffmpy-0.3.0 filelock-3.8.0 frozenlist-1.3.1 fsspec-2022.8.2 gradio-3.4.1 h11-0.12.0 httpcore-0.15.0 httpx-0.23.0 huggingface-hub-0.10.0 ipywidgets-8.0.2 jupyterlab-widgets-3.0.3 linkify-it-py-1.0.3 markdown-it-py-2.1.0 mdit-py-plugins-0.3.1 mdurl-0.1.2 multidict-6.0.2 orjson-3.8.0 paramiko-2.11.0 pycryptodome-3.15.0 pydantic-1.10.2 pydub-0.25.1 pynacl-1.5.0 python-multipart-0.0.5 regex-2022.9.13 rfc3986-1.5.0 sniffio-1.3.0 starlette-0.20.4 tokenizers-0.12.1 tqdm-4.64.1 transformers-4.22.2 typing-extensions-4.4.0 uc-micro-py-1.0.1 uvicorn-0.18.3 websockets-10.3 widgetsnbextension-4.0.3 yarl-1.8.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-gpu 2.5.0 requires numpy~=1.19.2, but you have numpy 1.22.3 which is incompatible.
# tensorflow-gpu 2.5.0 requires typing-extensions~=3.7.4, but you have typing-extensions 4.4.0 which is incompatible.
# WARNING: You are using pip version 22.0.4; however, version 22.2.2 is available.
# You should consider upgrading via the 'c:\users\user\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %%
# !pip install numpy==1.19.2
# Out:
# Collecting numpy==1.19.2
#   Downloading numpy-1.19.2.zip (7.3 MB)
#      ---------------------------------------- 7.3/7.3 MB 7.8 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Building wheels for collected packages: numpy
#   Building wheel for numpy (pyproject.toml): started
#   Building wheel for numpy (pyproject.toml): finished with status 'done'
#   Created wheel for numpy: filename=numpy-1.19.2-cp39-cp39-win_amd64.whl size=4861166 sha256=42fa8d8bb77c64ed7653191aeb4251b9c9279c241ca948d19614f355a981f47c
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\a3\17\dd\f2dba23a35bb6008732772ccfb13d3d0e537fbc6919ce6862b
# Successfully built numpy
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.22.3
#     Uninstalling numpy-1.22.3:
#       Successfully uninstalled numpy-1.22.3
# Successfully installed numpy-1.19.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.8.0 requires numpy>=1.20, but you have numpy 1.19.2 which is incompatible.
# tensorflow-gpu 2.5.0 requires typing-extensions~=3.7.4, but you have typing-extensions 4.4.0 which is incompatible.
# opencv-python 4.6.0.66 requires numpy>=1.19.3; python_version >= "3.9", but you have numpy 1.19.2 which is incompatible.
# opencv-python-headless 4.5.4.60 requires numpy>=1.19.3, but you have numpy 1.19.2 which is incompatible.
# opencv-contrib-python 4.6.0.66 requires numpy>=1.19.3; python_version >= "3.9", but you have numpy 1.19.2 which is incompatible.
# h5py 3.1.0 requires numpy>=1.19.3; python_version >= "3.9", but you have numpy 1.19.2 which is incompatible.
# WARNING: You are using pip version 22.0.4; however, version 22.2.2 is available.
# You should consider upgrading via the 'c:\users\user\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %%
import gradio as gr    #UI
from transformers import pipeline  #pipeline
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ImportError: numpy.core._multiarray_umath failed to import
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ImportError: numpy.core.umath failed to import
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\transformers\utils\import_utils.py in _get_module(self, module_name)
#    1030         try:
# -> 1031             return importlib.import_module("." + module_name, self.__name__)
#    1032         except Exception as e:
#
# c:\users\user\appdata\local\programs\python\python39\lib\importlib\__init__.py in import_module(name, package)
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#
# c:\users\user\appdata\local\programs\python\python39\lib\importlib\_bootstrap.py in _gcd_import(name, package, level)
#
# c:\users\user\appdata\local\programs\python\python39\lib\importlib\_bootstrap.py in _find_and_load(name, import_)
#
# c:\users\user\appdata\local\programs\python\python39\lib\importlib\_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# c:\users\user\appdata\local\programs\python\python39\lib\importlib\_bootstrap.py in _load_unlocked(spec)
#
# c:\users\user\appdata\local\programs\python\python39\lib\importlib\_bootstrap_external.py in exec_module(self, module)
#
# c:\users\user\appdata\local\programs\python\python39\lib\importlib\_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\transformers\pipelines\__init__.py in <module>
#      38 from ..utils import HUGGINGFACE_CO_RESOLVE_ENDPOINT, is_tf_available, is_torch_available, logging
# ---> 39 from .audio_classification import AudioClassificationPipeline
#      40 from .automatic_speech_recognition import AutomaticSpeechRecognitionPipeline
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\transformers\pipelines\audio_classification.py in <module>
#      19 from ..utils import add_end_docstrings, is_torch_available, logging
# ---> 20 from .base import PIPELINE_INIT_ARGS, Pipeline
#      21
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\transformers\pipelines\base.py in <module>
#      33 from ..feature_extraction_utils import PreTrainedFeatureExtractor
# ---> 34 from ..modelcard import ModelCard
#      35 from ..models.auto.configuration_auto import AutoConfig
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\transformers\modelcard.py in <module>
#      43 )
# ---> 44 from .training_args import ParallelMode
#      45 from .utils import (
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\transformers\training_args.py in <module>
#      28 from .debug_utils import DebugOption
# ---> 29 from .trainer_utils import (
#      30     EvaluationStrategy,
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\transformers\trainer_utils.py in <module>
#      46 if is_tf_available():
# ---> 47     import tensorflow as tf
#      48
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\tensorflow\__init__.py in <module>
#      36
# ---> 37 from tensorflow.python.tools import module_util as _module_util
#      38 from tensorflow.python.util.lazy_loader import LazyLoader as _LazyLoader
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\tensorflow\python\__init__.py in <module>
#      41 # Bring in subpackages.
# ---> 42 from tensorflow.python import data
#      43 from tensorflow.python import distribute
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\tensorflow\python\data\__init__.py in <module>
#      20 # pylint: disable=unused-import
# ---> 21 from tensorflow.python.data import experimental
#      22 from tensorflow.python.data.ops.dataset_ops import AUTOTUNE
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\tensorflow\python\data\experimental\__init__.py in <module>
#      94 # pylint: disable=unused-import
# ---> 95 from tensorflow.python.data.experimental import service
#      96 from tensorflow.python.data.experimental.ops.batching import dense_to_ragged_batch
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\tensorflow\python\data\experimental\service\__init__.py in <module>
#     386
# --> 387 from tensorflow.python.data.experimental.ops.data_service_ops import distribute
#     388 from tensorflow.python.data.experimental.ops.data_service_ops import from_dataset_id
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\tensorflow\python\data\experimental\ops\data_service_ops.py in <module>
#      22 from tensorflow.python.compat import compat
# ---> 23 from tensorflow.python.data.experimental.ops import compression_ops
#      24 from tensorflow.python.data.experimental.service import _pywrap_server_lib
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\tensorflow\python\data\experimental\ops\compression_ops.py in <module>
#      15 """Ops for compressing and uncompressing dataset elements."""
# ---> 16 from tensorflow.python.data.util import structure
#      17 from tensorflow.python.ops import gen_experimental_dataset_ops as ged_ops
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\tensorflow\python\data\util\structure.py in <module>
#      21
# ---> 22 from tensorflow.python.data.util import nest
#      23 from tensorflow.python.framework import composite_tensor
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\tensorflow\python\data\util\nest.py in <module>
#      35
# ---> 36 from tensorflow.python.framework import sparse_tensor as _sparse_tensor
#      37 from tensorflow.python.util import _pywrap_utils
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\tensorflow\python\framework\sparse_tensor.py in <module>
#      23 from tensorflow.python.framework import composite_tensor
# ---> 24 from tensorflow.python.framework import constant_op
#      25 from tensorflow.python.framework import dtypes
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\tensorflow\python\framework\constant_op.py in <module>
#      24 from tensorflow.python.eager import context
# ---> 25 from tensorflow.python.eager import execute
#      26 from tensorflow.python.framework import dtypes
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\tensorflow\python\eager\execute.py in <module>
#      22 from tensorflow.python.eager import core
# ---> 23 from tensorflow.python.framework import dtypes
#      24 from tensorflow.python.framework import ops
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\tensorflow\python\framework\dtypes.py in <module>
#      28
# ---> 29 _np_bfloat16 = _pywrap_bfloat16.TF_bfloat16_type()
#      30
#
# TypeError: Unable to convert function return value to a Python type! The signature was
# 	() -> handle
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2172/2055648382.py in <module>
#       1 import gradio as gr
# ----> 2 from transformers import pipeline
#
# c:\users\user\appdata\local\programs\python\python39\lib\importlib\_bootstrap.py in _handle_fromlist(module, fromlist, import_, recursive)
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\transformers\utils\import_utils.py in __getattr__(self, name)
#    1019             value = self._get_module(name)
#    1020         elif name in self._class_to_module.keys():
# -> 1021             module = self._get_module(self._class_to_module[name])
#    1022             value = getattr(module, name)
#    1023         else:
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\transformers\utils\import_utils.py in _get_module(self, module_name)
#    1031             return importlib.import_module("." + module_name, self.__name__)
#    1032         except Exception as e:
# -> 1033             raise RuntimeError(
#    1034                 f"Failed to import {self.__name__}.{module_name} because of the following error (look up to see its"
#    1035                 f" traceback):\n{e}"
#
# RuntimeError: Failed to import transformers.pipelines because of the following error (look up to see its traceback):
# Unable to convert function return value to a Python type! The signature was
# 	() -> handle
